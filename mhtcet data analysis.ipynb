# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('kaggle_sw_raw.csv')

# %%
df.head()
# Out:
#     rank  percentile             branch gender     category fulfillment  \
# 0  18388   90.121473  Civil Engineering      M  NT 2 (NT-C)           ^
# 1  18898   89.889223  Civil Engineering      F           SC           ^
# 2  19374   89.540152  Civil Engineering      M          OBC           ^
# 3  21857   88.241971  Civil Engineering      M          OBC           ^
# 4  22128   88.091617  Civil Engineering      M        DT/VJ           ~
#
#   seat_type  primary_seat_type secondary_seat_type score_type  \
# 0    GOPENS  State Level Seats   State Level Seats    MHT-CET
# 1    LOPENS  State Level Seats   State Level Seats    MHT-CET
# 2    GOPENS  State Level Seats   State Level Seats    MHT-CET
# 3    GOPENS  State Level Seats   State Level Seats    MHT-CET
# 4    GOPENS  State Level Seats   State Level Seats    MHT-CET
#
#                                   college_name enrollment_no branch_code
# 0  Government College of Engineering, Amravati    EN22169138   100219110
# ...

# %%
df.shape
# Out:
# (104345, 13)

# %%
df.columns
# Out:
# Index(['rank', 'percentile', 'branch', 'gender', 'category', 'fulfillment',
#        'seat_type', 'primary_seat_type', 'secondary_seat_type', 'score_type',
#        'college_name', 'enrollment_no', 'branch_code'],
#       dtype='object')

# %%
len(df['rank'].unique())
# Out:
# 94274

# %%
df['rank'].isna().sum()
# Out:
# 0

# %%
len(df['percentile'].unique())
# Out:
# 6982

# %%
df['percentile'].isna().sum()
# Out:
# 0

# %%
df['branch'].unique()

# %%
df['fulfillment'].unique()
# Out:
# array(['^', '~', '*', '&', '@'], dtype=object)

# %%
df.drop('fulfillment',axis=1,inplace=True)

# %%
df.head()
# Out:
#     rank  percentile             branch gender     category seat_type  \
# 0  18388   90.121473  Civil Engineering      M  NT 2 (NT-C)    GOPENS
# 1  18898   89.889223  Civil Engineering      F           SC    LOPENS
# 2  19374   89.540152  Civil Engineering      M          OBC    GOPENS
# 3  21857   88.241971  Civil Engineering      M          OBC    GOPENS
# 4  22128   88.091617  Civil Engineering      M        DT/VJ    GOPENS
#
#    primary_seat_type secondary_seat_type score_type  \
# 0  State Level Seats   State Level Seats    MHT-CET
# 1  State Level Seats   State Level Seats    MHT-CET
# 2  State Level Seats   State Level Seats    MHT-CET
# 3  State Level Seats   State Level Seats    MHT-CET
# 4  State Level Seats   State Level Seats    MHT-CET
#
#                                   college_name enrollment_no branch_code
# 0  Government College of Engineering, Amravati    EN22169138   100219110
# 1  Government College of Engineering, Amravati    EN22182921   100219110
# ...

# %%
df.drop(['enrollment_no','branch_code'],axis=1,inplace=True)

# %%
df['score_type'].unique()
# Out:
# array(['MHT-CET', 'JEE(Main)', 'Merit'], dtype=object)

# %%
df['primary_seat_type'].unique()
# Out:
# array(['State Level Seats', 'Maharashtra State Seats', 'All India Seats',
#        'Maharashtra State Seats Allotted to All India Candidature Candidates'],
#       dtype=object)

# %%
df['secondary_seat_type'].unique()
# Out:
# array(['State Level Seats',
#        'Home University Seats Allotted to Home University Candidates',
#        'Home University Seats Allotted to Other Than Home University Candidates',
#        'Other Than Home University Seats Allotted to Other Than Home University Candidates',
#        'Economically Weaker Section Seats',
#        'Other Than Home University Seats Allotted to Home University Candidates',
#        'ORPHAN Seats',
#        'All India Seats Allotted to All India Candidature Candidates with JEE(Main) Score',
#        'All India Seats Allotted to All India Candidature Candidates with MHT-CET Score',
#        'Maharashtra State Seats Allotted to All India Candidature Candidates with JEE(Main) Score',
#        'Diploma Candidates',
#        'Maharashtra State Seats Allotted to All India Candidature Candidates with MHT-CET Score'],
#       dtype=object)

# %% [markdown]
# First lets try grouping by branch and category with min and max rank and percentile

# %%
df.groupby(['branch','category'])['rank','percentile'].min().reset_index()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1120\1032288426.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['branch','category'])['rank','percentile'].min().reset_index()
#                         branch       category    rank  percentile
# 0     Aeronautical Engineering          DT/VJ   31436   48.939024
# 1     Aeronautical Engineering     DT/VJ/DEF1   67788   59.682905
# 2     Aeronautical Engineering    NT 1 (NT-B)   34973   42.424054
# 3     Aeronautical Engineering  NT 1 (NT-B)$#  101446   29.234282
# 4     Aeronautical Engineering    NT 2 (NT-C)   72828   22.169426
# ...                        ...            ...     ...         ...
# 1371        Textile Technology            SBC   21097   10.456483
# 1372        Textile Technology           SBC$  110063   19.107271
# 1373        Textile Technology             SC   23469   12.219415
# ...

# %%
df.groupby(['branch','category'])['rank','percentile'].max().reset_index()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1120\3436145597.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['branch','category'])['rank','percentile'].max().reset_index()
#                         branch       category    rank  percentile
# 0     Aeronautical Engineering          DT/VJ   81045   53.110368
# 1     Aeronautical Engineering     DT/VJ/DEF1   67788   59.682905
# 2     Aeronautical Engineering    NT 1 (NT-B)   86733   80.916727
# 3     Aeronautical Engineering  NT 1 (NT-B)$#  101446   29.234282
# 4     Aeronautical Engineering    NT 2 (NT-C)  107695   55.890292
# ...                        ...            ...     ...         ...
# 1371        Textile Technology            SBC  116569   88.647595
# 1372        Textile Technology           SBC$  110063   19.107271
# 1373        Textile Technology             SC  115094   87.324411
# ...

# %%
df['category'].unique()
# Out:
# array(['NT 2 (NT-C)', 'SC', 'OBC', 'DT/VJ', 'NT 1 (NT-B)', 'SC$',
#        'NT 1 (NT-B)$#', 'SBC', 'OBC$', 'OBC#', 'ST', 'NT 3 (NT-D)',
#        'ST/DEF2', 'ST$', 'OBC/DEF1', 'OPEN', 'Open/DEF3', 'SC/DEF1',
#        'SC/DEF2', 'OBC/PH1', 'Open/PH1', 'Open/DEF1', 'OBC/DEF2',
#        'NT 3 (NT-D)#', 'SC$/DEF1', 'SBC$', 'DT/VJ$#', 'NT 1 (NT-B)/DEF1',
#        'OBC$#', 'NT 1 (NT-B)$', 'NT 3 (NT-D)$#', 'DT/VJ$', 'ST/PH1',
#        'NT 3 (NT-D)$', 'SBC/DEF1', 'NT 1 (NT-B)#', 'NT 2 (NT-C)$',
#        'NT 2 (NT-C)#', 'DT/VJ#', 'NT 2 (NT-C)$#', 'DT/VJ/PH1',
#        'OBC$/DEF1', 'NT 2 (NT-C)/PH1', 'SC/PH1', 'NT 3 (NT-D)/DEF1',
#        'Open/DEF2', 'SBC#', 'NT 2 (NT-C)/DEF1', 'NT 2 (NT-C)/DEF2',
#        'SBC$#', 'OBC$/PH1', 'DT/VJ/DEF1', 'OBC$#/DEF1', 'OBC/DEF3',
#        'NT 1 (NT-B)/DEF2', 'NT 1 (NT-B)/PH1', 'SBC/PH1', 'OBC#/DEF1',
#        'OBC#/PH1', 'ST/DEF1', 'SC/DEF3', 'OBC$#/PH1', 'NT 2 (NT-C)$/PH1',
#        'NT 3 (NT-D)/PH1', 'SBC$/PH1', 'NT 3 (NT-D)/DEF2', 'SBC#/DEF1',
# ...

# %%
df.head()
# Out:
#     rank  percentile             branch gender     category seat_type  \
# 0  18388   90.121473  Civil Engineering      M  NT 2 (NT-C)    GOPENS
# 1  18898   89.889223  Civil Engineering      F           SC    LOPENS
# 2  19374   89.540152  Civil Engineering      M          OBC    GOPENS
# 3  21857   88.241971  Civil Engineering      M          OBC    GOPENS
# 4  22128   88.091617  Civil Engineering      M        DT/VJ    GOPENS
#
#    primary_seat_type secondary_seat_type score_type  \
# 0  State Level Seats   State Level Seats    MHT-CET
# 1  State Level Seats   State Level Seats    MHT-CET
# 2  State Level Seats   State Level Seats    MHT-CET
# 3  State Level Seats   State Level Seats    MHT-CET
# 4  State Level Seats   State Level Seats    MHT-CET
#
#                                   college_name
# 0  Government College of Engineering, Amravati
# 1  Government College of Engineering, Amravati
# 2  Government College of Engineering, Amravati
# ...

# %% [markdown]
# Now groupby college and category to find min and max percentile and rank

# %%
df.groupby(['college_name','category'])['rank','percentile'].min().reset_index()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1120\3125339874.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['college_name','category'])['rank','percentile'].min().reset_index()
#                                            college_name      category   rank  \
# 0             A. P. Shah Institute of Technology, Thane         DT/VJ  33810
# 1             A. P. Shah Institute of Technology, Thane   NT 1 (NT-B)  11546
# 2             A. P. Shah Institute of Technology, Thane  NT 1 (NT-B)$  44877
# 3             A. P. Shah Institute of Technology, Thane   NT 2 (NT-C)  20898
# 4             A. P. Shah Institute of Technology, Thane   NT 3 (NT-D)  35118
# ...                                                 ...           ...    ...
# 5462  Zeal Education Society's Zeal College of Engin...         SBC$#  58722
# 5463  Zeal Education Society's Zeal College of Engin...            SC  11726
# ...

# %%
df.groupby(['college_name','category'])['rank','percentile'].max().reset_index()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1120\2937801075.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['college_name','category'])['rank','percentile'].max().reset_index()
#                                            college_name      category    rank  \
# 0             A. P. Shah Institute of Technology, Thane         DT/VJ   33810
# 1             A. P. Shah Institute of Technology, Thane   NT 1 (NT-B)  116163
# 2             A. P. Shah Institute of Technology, Thane  NT 1 (NT-B)$   44877
# 3             A. P. Shah Institute of Technology, Thane   NT 2 (NT-C)   68682
# 4             A. P. Shah Institute of Technology, Thane   NT 3 (NT-D)   54461
# ...                                                 ...           ...     ...
# 5462  Zeal Education Society's Zeal College of Engin...         SBC$#   58722
# 5463  Zeal Education Society's Zeal College of Engin...            SC  120664
# ...

# %%
df.head()
# Out:
#     rank  percentile             branch gender     category seat_type  \
# 0  18388   90.121473  Civil Engineering      M  NT 2 (NT-C)    GOPENS
# 1  18898   89.889223  Civil Engineering      F           SC    LOPENS
# 2  19374   89.540152  Civil Engineering      M          OBC    GOPENS
# 3  21857   88.241971  Civil Engineering      M          OBC    GOPENS
# 4  22128   88.091617  Civil Engineering      M        DT/VJ    GOPENS
#
#    primary_seat_type secondary_seat_type score_type  \
# 0  State Level Seats   State Level Seats    MHT-CET
# 1  State Level Seats   State Level Seats    MHT-CET
# 2  State Level Seats   State Level Seats    MHT-CET
# 3  State Level Seats   State Level Seats    MHT-CET
# 4  State Level Seats   State Level Seats    MHT-CET
#
#                                   college_name
# 0  Government College of Engineering, Amravati
# 1  Government College of Engineering, Amravati
# 2  Government College of Engineering, Amravati
# ...

# %%
df.groupby('score_type').size().reset_index().rename(columns={0:'Total'})
# Out:
#   score_type  Total
# 0  JEE(Main)  11363
# 1    MHT-CET  92651
# 2      Merit    331

# %% [markdown]
# Which college accepts the maximum mhtcet score type

# %%
df.groupby(['score_type','college_name']).size().reset_index().rename(columns={0:'Total'}).sort_values('Total',ascending=False)
# Out:
#     score_type                                       college_name  Total
# 455    MHT-CET  Lokmanya Tilak Jankalyan Shikshan Sanstha, Pri...   1184
# 336    MHT-CET  Bansilal Ramnath Agarawal Charitable Trust's V...   1140
# 632    MHT-CET  Yeshwantrao Chavan College of Engineering,Wana...   1060
# 334    MHT-CET  B.R.A.C.T's Vishwakarma Institute of Informati...   1041
# 329    MHT-CET  Ankush Shikshan Sanstha's G.H.Raisoni College ...    989
# ..         ...                                                ...    ...
# 47   JEE(Main)  Department of Technology, Shivaji University, ...      1
# 657      Merit  Leela Education Society, G.V. Acharya Institut...      1
# 662      Merit  Mahatma Education Society's Pillai College of ...      1
# 661      Merit  Mahatma Basaweshwar Education Society's Colleg...      1
# 689      Merit  Yadavrao Tasgaonkar College of Engineering & M...      1
#
# [690 rows x 3 columns]

# %%
df.head()
# Out:
#     rank  percentile             branch gender     category seat_type  \
# 0  18388   90.121473  Civil Engineering      M  NT 2 (NT-C)    GOPENS
# 1  18898   89.889223  Civil Engineering      F           SC    LOPENS
# 2  19374   89.540152  Civil Engineering      M          OBC    GOPENS
# 3  21857   88.241971  Civil Engineering      M          OBC    GOPENS
# 4  22128   88.091617  Civil Engineering      M        DT/VJ    GOPENS
#
#    primary_seat_type secondary_seat_type score_type  \
# 0  State Level Seats   State Level Seats    MHT-CET
# 1  State Level Seats   State Level Seats    MHT-CET
# 2  State Level Seats   State Level Seats    MHT-CET
# 3  State Level Seats   State Level Seats    MHT-CET
# 4  State Level Seats   State Level Seats    MHT-CET
#
#                                   college_name
# 0  Government College of Engineering, Amravati
# 1  Government College of Engineering, Amravati
# 2  Government College of Engineering, Amravati
# ...

# %% [markdown]
# Groupby branch and gender

# %%
df.groupby(['branch','gender']).size().reset_index().sort_values(0,ascending=False)
# Out:
#                                      branch gender      0
# 33                     Computer Engineering      M  12846
# 125                  Mechanical Engineering      M  10341
# 95   Electronics and Telecommunication Engg      M   9365
# 111                  Information Technology      M   6473
# 41         Computer Science and Engineering      M   6373
# ..                                      ...    ...    ...
# 155                      Plastic Technology      M      2
# 138               Oil and Paints Technology      F      1
# 174             Safety and Fire Engineering      M      1
# 154                      Plastic Technology      F      1
# 169                                Robotics      M      1
#
# [186 rows x 3 columns]
